# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\Sale_Prediction\notebooks\data\advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.pairplot(data,x_vars=["TV","Radio","Newspaper"],y_vars="Sales",kind="reg",plot_kws={'line_kws':{'color':'red'}})

# %% [markdown]
# From the Figure, As the TV advertisement cost is increase the sale of TV is also increase

# %%
sns.heatmap(data.corr(),annot=True,cmap="viridis")
# Out:
# <Axes: >

# %%
plt.hist(data["TV"])
# Out:
# (array([26., 15., 21., 18., 19., 17., 22., 26., 20., 16.]),
#  array([  0.7 ,  30.27,  59.84,  89.41, 118.98, 148.55, 178.12, 207.69,
#         237.26, 266.83, 296.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Radio"],color="Green")
# Out:
# (array([30., 20., 21., 17., 18., 23., 14., 21., 21., 15.]),
#  array([ 0.  ,  4.96,  9.92, 14.88, 19.84, 24.8 , 29.76, 34.72, 39.68,
#         44.64, 49.6 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Newspaper"],color="yellow")
# Out:
# (array([47., 41., 35., 30., 21., 13.,  9.,  2.,  1.,  1.]),
#  array([  0.3 ,  11.67,  23.04,  34.41,  45.78,  57.15,  68.52,  79.89,
#          91.26, 102.63, 114.  ]),
#  <BarContainer object of 10 artists>)

# %%
sns.regplot(x=data["TV"], y=data["Sales"],color="red")

plt.xlabel("TV Budget")
plt.ylabel("Sales")
plt.title("Scatter Plot of TV vs Sales")

plt.show()

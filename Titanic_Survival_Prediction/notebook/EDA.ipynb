# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Titanic_Survival_Prediction\notebook\data\Titanic-Dataset.csv")

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.shape
# Out:
# (891, 12)

# %%
data["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Peoples are not Survived
#
# 1 --> Peoples are Survived

# %%
sns.countplot(x=data["Survived"],hue=data["Survived"])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
selected_columns = data[["Pclass","SibSp","Parch","Age","Fare","Survived"]]
correlation_matrix = selected_columns.corr()

sns.heatmap(data=correlation_matrix, annot=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x=data["Survived"],hue=data["Sex"])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>
